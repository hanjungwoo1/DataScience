# %% [markdown]
# # 3. 캐글 경진대회 도전 (1). 타이타닉 생존자 예측
#
# ## 3.1 캐글을 이용한 데이터 분석
#
# #### 이 장의 데이터 분석 흐름
#  - 데이터 분석을 위한 파이썬 코드 익히기
#  - 추가 분석 1 : 승객을 그룹별로 분류하기
#  - 추가 분석 2 : 특정 타깃에 주목하기
#
# ## 3.2 타이타닉 생존자 예측 경진대회란
#
# ## 3.3 데이터 내려받기
#
# ## 3.4 데이터 분석을 위한 준비 작업
# #### 아나콘다에서 환경 설정
# #### 주피터 노트북

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv("../data/titanic/train.csv")
test_df = pd.read_csv("../data/titanic/test.csv")
submission = pd.read_csv("../data/titanic/gender_submission.csv")

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
import random
np.random.seed(940107)
random.seed(940107)

# %% [markdown]
# ## 3.5 데이터 개요 파악
#
# 이 절 및 다음 3.6절과 같은 접근을 **탐색적 데이터 해석(Exploratory Data Analysis, EDA)**
#
# #### 데이터의 행과 열 확인하기

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (891, 12)
# (418, 11)

# %% [markdown]
# #### 데이터 내용 미리보기
#
# 데이터프레임명.head()라는 명령어를 이용하여 맨 앞쪽의 몇 행을 표시

# %%
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 50)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# #### 데이터 속성 확인하기
#
# 데이터 속성을 확인
# 수치 : 정수 int형, 소수 float형, int나 float뒤의 숫자는 비트(bit)수

# %%
train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
test_df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# |  |  |개요|예|
# |----|----|----|----|
# |질적 변수| 명목 척도|분류를 위한 것|생존 여부(방 번호, 티켓 번호 등도 원래는 명목 척도에 해당되지만, 지금 데이터에는 알파벳이 포함되어 있으서 문자열로 취급|
# |질적 변수|순서 척도|순서에 의미가 있는 것|티켓 등급|
# |양적 변수|간격 척도|간격을 측정하는 것|눈금이 곧 간격인 것(이번 데이터에는 없지만 온도 등이 해당|
# |양적 변수|비례 척도|비율에 의미가 있는 것|연령, 티켓 요금, 가족 구성원 수|
#
# #### 데이터의 통계량 확인하기
#
# 주어진 데이터 중 먼저 수치 데이터 개요를 파악

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test_df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# #### 카테고리 변수 확인하기
#
# 테이터프레임명["열명"] 형태로 개별 열에서 원하는 데이터 추출할 수 있습니다. 특정 열을 뽑아낸 데이터를 **시리즈(Series)** 라고 합니다.
#
# 데이터프레임명["열명"].value_counts()라는 코드로 지정된 열(Series)에 포함된 값들과 중복 횟수 등을 확인

# %%
train_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_df["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
train_df["Name"].value_counts()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %%
train_df["Ticket"].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# #### 결측치 확인하기
# 데이터프레임명.isnull()

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ## 3.6 데이터의 시각화
#
# #### 시각화용 라이브러리 설치하고 불러오기
# matplotlib, seaborn

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 표시 스타일 정하기

# %%
plt.style.use("ggplot")

# %% [markdown]
# ### 3.6.1 목벅 변수 관련 데이터의 시각화
# 이제 목적 변수인 Survived에 관한 데이터 시각화를 진행
#
# #### 데이터프레임에서 임의의 열 추출하기

# %%
train_df[["Embarked", "Survived", "PassengerId"]]
# Out:
#     Embarked  Survived  PassengerId
# 0          S         0            1
# 1          C         1            2
# 2          S         1            3
# 3          S         1            4
# 4          S         0            5
# ..       ...       ...          ...
# 886        S         0          887
# 887        S         1          888
# 888        S         0          889
# 889        C         1          890
# 890        Q         0          891
#
# [891 rows x 3 columns]

# %% [markdown]
# #### 시각화하고 싶은 데이터에서 결측치 제외하기
# 데이터프레임명.dropna() 실행

# %%
train_df[["Embarked", "Survived", "PassengerId"]].dropna()
# Out:
#     Embarked  Survived  PassengerId
# 0          S         0            1
# 1          C         1            2
# 2          S         1            3
# 3          S         1            4
# 4          S         0            5
# ..       ...       ...          ...
# 886        S         0          887
# 887        S         1          888
# 888        S         0          889
# 889        C         1          890
# 890        Q         0          891
#
# [889 rows x 3 columns]

# %% [markdown]
# #### Embarked와 Survived로만 집계하기

# %%
train_df[["Embarked", "Survived", "PassengerId"]].dropna().groupby(["Embarked", "Survived"]).count()
# Out:
#                    PassengerId
# Embarked Survived
# C        0                  75
#          1                  93
# Q        0                  47
#          1                  30
# S        0                 427
#          1                 217

# %% [markdown]
# #### 데이터를 수평으로 변환하기
# 데이터를 정렬하는 방법에는 **수직정렬, 수평정렬**
#
# **unstack()**으로 수직 데이터를 수평 데이터 형태로 변환

# %%
embarked_df = train_df[["Embarked", "Survived", "PassengerId"]].dropna().groupby(["Embarked", "Survived"]).count().unstack()

# %%
embarked_df
# Out:
#          PassengerId
# Survived           0    1
# Embarked
# C                 75   93
# Q                 47   30
# S                427  217

# %% [markdown]
# #### 누적 막대 그래프로 시각화하기

# %%
embarked_df.plot.bar(stacked=True)

# %%
embarked_df.plot.bar()

# %% [markdown]
# #### 수치로 확인하기
# 데이터프래임명.iloc[행 번호, 열 번호]로 임의의 행과 열을 추출

# %%
embarked_df.iloc[:,0]
# Out:
# Embarked
# C     75
# Q     47
# S    427
# Name: (PassengerId, 0), dtype: int64

# %%
embarked_df.iloc[:,1]
# Out:
# Embarked
# C     93
# Q     30
# S    217
# Name: (PassengerId, 1), dtype: int64

# %%
embarked_df
# Out:
#          PassengerId
# Survived           0    1
# Embarked
# C                 75   93
# Q                 47   30
# S                427  217

# %%
embarked_df["survived_rate"] = embarked_df.iloc[:,0] / (embarked_df.iloc[:,0] + embarked_df.iloc[:,1])

# %%
embarked_df
# Out:
#          PassengerId      survived_rate
# Survived           0    1
# Embarked
# C                 75   93      0.446429
# Q                 47   30      0.610390
# S                427  217      0.663043

# %% [markdown]
# #### 성별과 티켓 등급 시각화하기

# %%
sex_df = train_df[["Sex", "Survived", "PassengerId"]].dropna().groupby(["Sex", "Survived"]).count().unstack()

# %%
sex_df.plot.bar()

# %%
sex_df.plot.bar(stacked=True)

# %%
ticket_df = train_df[["Pclass", "Survived", "PassengerId"]].dropna().groupby(["Pclass", "Survived"]).count().unstack()

# %%
ticket_df.plot.bar()

# %%
ticket_df.plot.bar(stacked=True)

# %% [markdown]
# #### 연령별 생존율을 히스토그램으로 시각화하기
# 연령은 연속 값이므로 **히스토그램**
#
# 데이터프레임명.hist() 혹은 plt.hist()라고 실행해야 합니다.
#
# 여러 히스토그램이 동시에 보이게 하려면 인수의 histtype을 barstacked
#
# 히스토그램 빈 개수를 나타내는 bins, 라벨을 지정하는 label 등이 있습니다.

# %%
plt.hist(x=[train_df.Age[train_df.Survived==0], train_df.Age[train_df.Survived==1]], bins = 8, histtype='barstacked', label=["Death", "Survived"])
# Out:
# (array([[ 26.,  71., 146.,  86.,  53.,  25.,  13.,   4.],
#         [ 64., 115., 230., 155.,  86.,  42.,  17.,   5.]]),
#  array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#         70.0525, 80.    ]),
#  <a list of 2 Lists of Patches objects>)

# %% [markdown]
# #### 카테고리 변수를 더비 변수화하기
# 카테고리 변수를 수치 데이터로 변환하려면 **원-핫 인코딩**을 사용해야 합니다.
#
# 원-핫 인코딩 : 어떤 케타고리 변수에 대하여 그 값인지 여부를 1, 0으로 나타내는 방법
#
# 1, 0으로 나타내는 것을 **더미(dummy) 변수화한다**고도 합니다.

# %%
train_df_corr = pd.get_dummies(train_df, columns=["Sex"])

# %%
train_df_corr.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Sex_female  Sex_male
# 0         A/5 21171   7.2500   NaN        S           0         1
# 1          PC 17599  71.2833   C85        C           1         0
# 2  STON/O2. 3101282   7.9250   NaN        S           1         0
# ...

# %%
train_df_corr = pd.get_dummies(train_df, columns=["Sex"], drop_first=True)

# %%
train_df_corr.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Sex_male
# 0         A/5 21171   7.2500   NaN        S         1
# 1          PC 17599  71.2833   C85        C         0
# 2  STON/O2. 3101282   7.9250   NaN        S         0
# 3            113803  53.1000  C123        S         0
# ...

# %%
train_df_corr = pd.get_dummies(train_df_corr, columns=["Embarked"])

# %%
train_df_corr.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_male  Embarked_C  Embarked_Q  \
# 0         A/5 21171   7.2500   NaN         1           0           0
# 1          PC 17599  71.2833   C85         0           1           0
# 2  STON/O2. 3101282   7.9250   NaN         0           0           0
# ...

# %% [markdown]
# #### 상관 행렬 작성하기
# **데이터프레임명.corr()** 형태로 각 변수 간 상관 계수를 계산

# %%
train_corr = train_df_corr.corr()

# %%
train_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Sex_male        0.042939 -0.543351  0.131900  0.093254 -0.114631 -0.245489
# Embarked_C     -0.001205  0.168240 -0.243292  0.036261 -0.059528 -0.011069
# Embarked_Q     -0.033606  0.003650  0.221009 -0.022405 -0.026354 -0.081228
# Embarked_S      0.022148 -0.155660  0.081720 -0.032523  0.070941  0.063036
#
#                  Fare  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# ...

# %% [markdown]
# #### 히트맵으로 시각화하기
#
# 시각화 라이브로리 씨본의 히트맵(heatmap) 기능을 이용
#
# annot을 True로 설정하면 상관 행렬 중 상관 계수가 각 칸에 숫자로 나타납니다.

# %%
plt.figure(figsize=(9,9))
sns.heatmap(train_corr, vmax =1, vmin = -1, center = 0, annot = True, cmap="Blues")

# %% [markdown]
# ## 3.7 데이터 전처리와 특징 값 생성
#
#
#
# #### 전처리할 데이터
#
#
# #### 학습 데이터와 테스트 데이터의 통합

# %%
all_df = pd.concat([train_df, test_df], sort=False).reset_index(drop=True)

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
all_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
Fare_mean = all_df[["Pclass", "Fare"]].groupby("Pclass").mean().reset_index()

# %%
Fare_mean.columns = ["Pclass", "Fare_mean"]

# %%
Fare_mean
# Out:
#    Pclass  Fare_mean
# 0       1  87.508992
# 1       2  21.179196
# 2       3  13.302889

# %%
all_df = pd.merge(all_df, Fare_mean, on="Pclass", how="left")
all_df.loc[(all_df["Fare"].isnull()), "Fare"] = all_df["Fare_mean"]
all_df = all_df.drop("Fare_mean", axis =1)

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
all_df["Name"].head(5)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
name_df = all_df["Name"].str.split("[,.]", 2, expand=True)

# %%
name_df.columns = ["family_name", "honorific", "name"]

# %%
name_df
# Out:
#         family_name honorific                                    name
# 0            Braund        Mr                             Owen Harris
# 1           Cumings       Mrs   John Bradley (Florence Briggs Thayer)
# 2         Heikkinen      Miss                                   Laina
# 3          Futrelle       Mrs           Jacques Heath (Lily May Peel)
# 4             Allen        Mr                           William Henry
# ...             ...       ...                                     ...
# 1304        Spector        Mr                                   Woolf
# 1305  Oliva y Ocana      Dona                                 Fermina
# 1306        Saether        Mr                         Simon Sivertsen
# 1307           Ware        Mr                               Frederick
# 1308          Peter    Master                               Michael J
#
# [1309 rows x 3 columns]

# %%
name_df["family_name"] = name_df["family_name"].str.strip()
name_df["honorific"] = name_df["honorific"].str.strip()
name_df["name"] = name_df["name"].str.strip()

# %%
name_df["honorific"].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Major             2
# Ms                2
# Lady              1
# Sir               1
# Mme               1
# Don               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: honorific, dtype: int64
